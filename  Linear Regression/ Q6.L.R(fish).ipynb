# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error

# %%
df = pd.read_csv('data/fish.csv')
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
# from pandas.plotting import satter_matrix
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df)
plt.show()

# %% [markdown]
# ###X['L1squared'] = np.square(df.Length1)

# %%
df = pd.get_dummies(df)

X = df.drop(columns = ["Weight"])

y = df["Weight"]

# %% [markdown]
# ### Split a data into Train and Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1)
X_train.shape
# Out:
# (119, 12)

# %% [markdown]
# ### Evaluating a model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
print("R^2: ", model.score(X_train, y_train))

y_predict = model.predict(X_test)
RMSE = root_mean_squared_error(y_test, y_predict)
print("RMSE: ", RMSE)
# Out:
# R^2:  0.9406750115439331
# RMSE:  103.43601101632

# %%
df["L1_Squared"] = np.square(df.Length1)
df["L2_Squared"] = np.square(df.Length2)
df["L3_Squared"] = np.square(df.Length3)
df["H_squared"] = np.square(df.Height)
df["Wsquared"] = np.square(df.Width)
df.head()
# Out:
#    Weight  Length1  Length2  Length3   Height   Width  Species_Bream  \
# 0   242.0     23.2     25.4     30.0  11.5200  4.0200           True
# 1   290.0     24.0     26.3     31.2  12.4800  4.3056           True
# 2   340.0     23.9     26.5     31.1  12.3778  4.6961           True
# 3   363.0     26.3     29.0     33.5  12.7300  4.4555           True
# 4   430.0     26.5     29.0     34.0  12.4440  5.1340           True
#
#    Species_Parkki  Species_Perch  Species_Pike  Species_Roach  Species_Smelt  \
# 0           False          False         False          False          False
# 1           False          False         False          False          False
# 2           False          False         False          False          False
# 3           False          False         False          False          False
# 4           False          False         False          False          False
#
#    Species_Whitefish  L1_Squared  L2_Squared  L3_Squared   H_squared  \
# ...

# %%
df = pd.get_dummies(df)

X = df.drop(columns = ["Weight"])

y = df["Weight"]

# %%
model= LinearRegression()

X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=1)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)

# %%
print("RMSE:", root_mean_squared_error(y_test, y_predict))
print("R^2: ", model.score(X,y))
# Out:
# RMSE: 46.02652013244924
# R^2:  0.983793513770051

# %% [markdown]
# ### PLOTIING

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test, y_predict, color="blue")
# plt.plot(y_test, y_predict, color="red")
plt.title("Fish Quadradic terms")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
