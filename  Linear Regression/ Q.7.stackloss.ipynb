# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.linear_model import LinearRegression
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('data/stackloss.csv')
df.head()
# Out:
#    AirFlow  WaterTemp  AcidConc  StackLoss
# 0       80         27        89         42
# 1       80         27        88         37
# 2       75         25        90         37
# 3       62         24        87         28
# 4       62         22        87         18

# %% [markdown]
# ### Finding values in quadratic terms

# %%
pd.plotting.scatter_matrix(df)
plt.show()

# %%
X = df.drop(columns = ["StackLoss"])
y = df["StackLoss"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("R^2: ", model.score(X,y))
y_predict = model.predict(X_test)
print("RMSE:", root_mean_squared_error(y_test, y_predict))
# Out:
# R^2:  0.9013813070763419
# RMSE: 3.772926357336113

# %%
df = np.sqrt(df[['AirFlow','WaterTemp']])
df.head()
# Out:
#     AirFlow  WaterTemp
# 0  2.990698   2.279507
# 1  2.990698   2.279507
# 2  2.942831   2.236068
# 3  2.806066   2.213364
# 4  2.806066   2.165737

# %% [markdown]
# ### Split a data into Train and Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = .25, random_state = 1)
X_train.shape
# Out:
# (15, 3)

# %% [markdown]
# ### Find R2 value with training data

# %%
model = LinearRegression()
model.fit(X_train, y_train)
print("R^2: ", model.score(X_train, y_train))
# Out:
# R^2:  0.9218135763620641

# %% [markdown]
# ### prediction and find RMSE value

# %%
y_predict = model.predict(X_test)
print("RMSE: ", root_mean_squared_error(y_test, y_predict))
# Out:
# RMSE:  3.772926357336113

# %% [markdown]
# ### Plotting

# %%
plt.scatter(y_test, y_predict, color = 'g')
plt.plot(y_test, y_predict, color = 'r')
plt.title("StackLoss values")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
