# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("wbcd.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0         13.50          15.64            86.97       549.1            0.1385
# 1         11.88          22.94            78.28       424.8            0.1213
# 2         12.41          26.44            79.93       471.4            0.1369
# 3         11.92          15.77            76.53       434.0            0.1367
# 4         16.20          15.73           104.50       819.1            0.1126
#
#    compactness_worst  concavity_worst  points_worst  symmetry_worst  \
# 0             0.1266          0.12420       0.09391          0.2827
# 1             0.2515          0.19160       0.07926          0.2940
# 2             0.1482          0.10670       0.07431          0.2998
# 3             0.1822          0.08669       0.08611          0.2102
# 4             0.1737          0.13620       0.08178          0.2487
#
#    dimension_worst
# 0          0.06771
# 1          0.07587
# 2          0.07881
# 3          0.06784
# 4          0.06766
#
# [5 rows x 32 columns]

# %%
X = df.drop(columns=['id','diagnosis'])
y = df.diagnosis

# %%
X_train, X_test,  y_train, y_test = train_test_split(X,y, test_size = .2, random_state = 5, stratify = y)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
print("Accuracy: ", model.score(X_test,y_test))
# Out:
# Accuracy:  0.9912280701754386

# %%
y_predict = model.predict(X_test)

conMax = confusion_matrix(y_test, y_predict)

tn,fp,fn,tp = conMax.ravel()
print("TN",tn,"FP",fp,"FN",fn,"TP",tp)
print(conMax)
# Out:
# TN 71 FP 1 FN 0 TP 42
# [[71  1]
#  [ 0 42]]

# %%
probability = model.predict_proba(X_test)
print(probability)
# Out:
# [[9.81142656e-07 9.99999019e-01]
#  [2.26165507e-03 9.97738345e-01]
#  [9.98736712e-01 1.26328849e-03]
#  [8.96974378e-05 9.99910303e-01]
#  [9.27843865e-04 9.99072156e-01]
#  [3.43833505e-01 6.56166495e-01]
#  [9.98849687e-01 1.15031348e-03]
#  [1.66381775e-09 9.99999998e-01]
#  [9.41020003e-01 5.89799965e-02]
#  [9.99872816e-01 1.27183922e-04]
#  [1.94328675e-07 9.99999806e-01]
#  [9.91332296e-01 8.66770386e-03]
#  [9.96336060e-01 3.66393986e-03]
#  [9.95010249e-01 4.98975149e-03]
#  [1.28316640e-07 9.99999872e-01]
#  [9.99869175e-01 1.30824590e-04]
#  [9.84529939e-01 1.54700606e-02]
#  [7.02773081e-06 9.99992972e-01]
#  [9.99316614e-01 6.83386200e-04]
#  [9.97338256e-01 2.66174389e-03]
#  [9.99091798e-01 9.08201606e-04]
#  [9.99982083e-01 1.79172331e-05]
#  [8.63313607e-05 9.99913669e-01]
#  [9.99093002e-01 9.06998249e-04]
#  [9.84690965e-01 1.53090355e-02]
#  [3.74183014e-03 9.96258170e-01]
#  [9.99920833e-01 7.91666410e-05]
#  [9.99651357e-01 3.48642943e-04]
#  [9.52212291e-01 4.77877093e-02]
#  [9.98601367e-01 1.39863318e-03]
#  [8.75855718e-01 1.24144282e-01]
#  [8.16305064e-01 1.83694936e-01]
#  [5.86243983e-05 9.99941376e-01]
#  [9.98569452e-01 1.43054814e-03]
