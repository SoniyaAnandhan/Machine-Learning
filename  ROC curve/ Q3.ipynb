# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score,confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("rocExample.csv")
print(df.head())
# Out:
#    instance actual  score
# 0         1      p   0.90
# 1         2      p   0.80
# 2         3      n   0.70
# 3         4      p   0.60
# 4         5      p   0.55

# %%
fpr,tpr,_ = roc_curve(df.actual,df.score,pos_label='p')
plt.plot(fpr,tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.savefig('rocdata.png')
plt.show()

# %%
Auc = roc_auc_score(df.actual,df.score)
print("Logistic: ROC AUC = %.3f" % (Auc))
print(f'Logistic: ROC AUC = { Auc:.3f}')
# Out:
# Logistic: ROC AUC = 0.680
# Logistic: ROC AUC = 0.680
